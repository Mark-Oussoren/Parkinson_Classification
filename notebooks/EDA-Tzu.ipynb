# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # NASA Orbit Classification - Exploratory Data Analysis
#
# EDA for the NASA Orbit Classification.

# %%
# Get maximum insights from a data set
# Uncover underlying structure
# Extract important variables from the dataset
# Detect outliers and anomalies(if any)
# Test underlying assumptions
# Determine the optimal factor settings

# %%
import os
print(os.getcwd())
# os.chdir('..')
# Out:
# /Users/lightning/repo/NASA-Orbit-Classification

# %%
raw = pd.read_csv('./data/raw/classast - pha.csv')
raw.head()
# Out:
#      a (AU)         e    i (deg)     w (deg)  Node (deg)     M (deg)  q (AU)  \
# 0  1.078066  0.826854  22.825495   31.382966   88.010681  215.528772  0.1867
# 1  1.245304  0.335342  13.337482  276.893024  337.207958  104.155607  0.8277
# 2  1.470264  0.559922   6.352995  285.852564   35.736768  174.626213  0.6470
# 3  1.776025  0.650141  39.832538  267.791993  356.903343  173.188556  0.6214
# 4  1.874123  0.764602   1.326399   43.388048  349.694944  235.158622  0.4412
#
#    Q (AU)  P (yr)  H (mag)  MOID (AU) class
# 0    1.97    1.12    16.90   0.034507  APO*
# 1    1.66    1.39    15.60   0.030669  APO*
# 2    2.29    1.78    16.25   0.025795  APO*
# 3    2.93    2.37    15.20   0.003551  APO*
# 4    3.31    2.57    18.80   0.011645  APO*

# %%
raw.isnull().sum()
# Out:
# a (AU)        0
# e             0
# i (deg)       0
# w (deg)       0
# Node (deg)    0
# M (deg)       0
# q (AU)        0
# Q (AU)        0
# P (yr)        0
# H (mag)       0
# MOID (AU)     0
# class         0
# dtype: int64

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1748 entries, 0 to 1747
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   a (AU)      1748 non-null   float64
#  1   e           1748 non-null   float64
#  2   i (deg)     1748 non-null   float64
#  3   w (deg)     1748 non-null   float64
#  4   Node (deg)  1748 non-null   float64
#  5   M (deg)     1748 non-null   float64
#  6   q (AU)      1748 non-null   float64
#  7   Q (AU)      1748 non-null   float64
#  8   P (yr)      1748 non-null   float64
#  9   H (mag)     1748 non-null   float64
#  10  MOID (AU)   1748 non-null   float64
#  11  class       1748 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 164.0+ KB

# %%
raw['class']
# Out:
# 0       APO*
# 1       APO*
# 2       APO*
# 3       APO*
# 4       APO*
#         ...
# 1743    AMO*
# 1744    APO*
# 1745    APO*
# 1746    APO*
# 1747    APO*
# Name: class, Length: 1748, dtype: object

# %%
#Checking for wrong entries like symbols -,?,#,*,etc.
# for col in raw.columns:
#     print('{} : {}'.format(col,raw[col].unique()))
# Out:
# a (AU) : [1.07806558 1.24530431 1.47026416 ... 2.03786953 2.09519302 2.80429433]
# e : [0.82685394 0.33534202 0.55992178 ... 0.66752499 0.65466191 0.66723636]
# i (deg) : [22.8254952 13.3374816  6.3529947 ...  8.9066493  4.014503   4.7248827]
# w (deg) : [ 31.3829659 276.8930236 285.8525637 ... 279.7219348 145.4296528
#  234.1259803]
# Node (deg) : [ 88.0106813 337.2079581  35.736768  ...  64.6902701  25.1645232
#  183.5746748]
# M (deg) : [215.5287722 104.1556065 174.6262134 ...  19.063147  340.7661049
#  349.5301596]
# q (AU) : [0.1867 0.8277 0.647  ... 0.6775 0.7235 0.9332]
# Q (AU) : [ 1.97  1.66  2.29  2.93  3.31  1.68  2.4   3.73  1.22  2.52  1.6   1.45
#   3.39  2.65  4.29  1.53  4.13  3.24  3.66  1.39  2.02  1.58  2.69  2.45
#   1.31  2.01  1.91  1.63  4.02  3.98  2.63  2.78  1.79  2.17  2.54  2.15
#   3.65  1.65  1.46  1.74  4.73  4.09  2.31  2.94  1.7   2.28  2.5   2.56
#   3.37  1.02  1.3   2.14  2.9   2.59  3.15  3.04  2.48  3.91  3.74  4.47
# ...

# %%
raw.shape[0]
# Out:
# 1748
